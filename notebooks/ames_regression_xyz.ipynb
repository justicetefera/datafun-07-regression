# %% [markdown]
# # Ames Housing XYZ Regression Notebook
# ### Red‑White‑Blue Visualization Edition (Artifacts)
#
# This notebook reproduces the functionality of the `ames_regression_xyz.py` module, including:
#
# - Logging
# - Dataset loading
# - Simple XYZ regressions
# - Saving artifacts to `docs/artifacts/xyz/`

# %%
"""
Ames Housing XYZ Regression Notebook
Red‑White‑Blue Visualization Edition (Artifacts)
"""

import logging
import os
import random
from typing import Final

from datafun_toolkit.logger import get_logger, log_header
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, root_mean_squared_error

# === LOGGER ===
LOG: logging.Logger = get_logger("JT‑XYZ", level="DEBUG")
log_header(LOG, "JT XYZ REGRESSIONS (Notebook)")

# === GLOBAL CONSTANTS ===
DATASET_NAME: Final[str] = "housing"
TARGET_COL: Final[str] = "SalePrice"

# Output folder for XYZ artifacts
OUTPUT_DIR: Final[str] = "docs/artifacts/xyz"
os.makedirs(OUTPUT_DIR, exist_ok=True)

pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

# === RED‑WHITE‑BLUE COLOR PALETTE ===
RWB_COLORS = ["#FF0000", "#FFFFFF", "#0000FF"]
# Out:
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | === RUN START ===
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | project=JT XYZ REGRESSIONS (Notebook)
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | repo_dir=datafun-07-regression
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | python=3.14.5
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | os=Windows 11
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | shell=powershell
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | cwd=notebooks
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | github_actions=False

# %% [markdown]
# ## Load the Ames Housing Data
#
# We now load the dataset from: `data/raw/housing.csv`
#
# This step logs row/column counts and previews the first few records.

# %% [markdown]
# ## Enable Inline Plot Rendering
#
# This command ensures that all Matplotlib plots appear directly below each cell output.
#
# ```python
# %matplotlib inline

# %%
def load_data() -> pd.DataFrame:
    """Load the Ames housing dataset."""
    LOG.info(f"Loading dataset: {DATASET_NAME}")
    df = pd.read_csv("../data/raw/housing.csv")
    LOG.info(f"Loaded: {df.shape[0]} rows, {df.shape[1]} columns")
    return df

# %% [markdown]
# ## Simple XYZ Regression Function
#
# This function performs a **simple linear regression** between a single feature
# (e.g., Garage Area, 1st Floor SF, or Total Rooms Above Ground) and **SalePrice**.
#
# It will:
#
# - Fit a linear regression model
# - Log the slope, intercept, R², and RMSE
# - Generate two red–white–blue visuals:
#   - Scatter plot with regression line
#   - Residual plot
# - Save both images to `docs/artifacts/xyz/`

# %%
def run_xyz_regression(feature_col: str, feature_label: str, tag: str):
    """Run a simple linear regression and save red-white-blue visuals."""
    log_header(LOG, f"XYZ REGRESSION: {feature_col}")

    df = load_data()
    df_model = df.dropna(subset=[feature_col, TARGET_COL]).copy()

    X = df_model[[feature_col]].to_numpy()
    y = df_model[TARGET_COL].to_numpy()

    model = LinearRegression()
    model.fit(X, y)

    slope = float(model.coef_[0])
    intercept = float(model.intercept_)

    LOG.info(
        f"Fitted line: {TARGET_COL} = {slope:.6g} * {feature_col} + {intercept:.6g}"
    )

    y_hat = model.predict(X)
    residuals = y - y_hat

    r2 = r2_score(y, y_hat)
    rmse = root_mean_squared_error(y, y_hat)

    LOG.info(f"R²: {r2:.4f}")
    LOG.info(f"RMSE: {rmse:,.2f}")

    # === Scatter Plot ===
    plt.figure()
    colors_scatter = [random.choice(RWB_COLORS) for _ in range(len(df_model))]
    plt.scatter(X, y, c=colors_scatter, edgecolors="black", linewidths=0.3)
    plt.plot(X, y_hat, color="black", linewidth=2)
    plt.xlabel(feature_label)
    plt.ylabel(TARGET_COL)
    plt.title(f"{feature_label} vs {TARGET_COL} (RWB Theme)")
    plt.savefig(f"{OUTPUT_DIR}/{tag}_scatter.png", dpi=300)
    plt.close()

    # === Residual Plot ===
    plt.figure()
    colors_resid = [random.choice(RWB_COLORS) for _ in range(len(df_model))]
    plt.scatter(X, residuals, c=colors_resid, edgecolors="black", linewidths=0.3)
    plt.axhline(0, color="black", linewidth=2)
    plt.xlabel(feature_label)
    plt.ylabel("Residuals")
    plt.title(f"Residuals vs {feature_label} (RWB Theme)")
    plt.savefig(f"{OUTPUT_DIR}/{tag}_residuals.png", dpi=300)
    plt.close()

    LOG.info("XYZ regression complete.")
    LOG.info("========================")

# %% [markdown]
# ## Run Simple XYZ Regressions
#
# We now run three separate simple linear regressions:
#
# 1. **Garage Area → SalePrice**
# 2. **1st Floor SF → SalePrice**
# 3. **Total Rooms Above Ground → SalePrice**
#
# Each regression will:
#
# - Fit a simple linear model
# - Log slope, intercept, R², and RMSE
# - Produce two red–white–blue visuals:
#   - Scatter plot with regression line
#   - Residual plot
# - Save all images to: `docs/artifacts/xyz/`

# %%
run_xyz_regression("Garage Area", "Garage Area (sq ft)", "garage_to_price")
run_xyz_regression("1st Flr SF", "First Floor Area (sq ft)", "firstfloor_to_price")
run_xyz_regression("TotRms AbvGrd", "Total Rooms Above Ground", "rooms_to_price")
# Out:
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | === RUN START ===
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | project=XYZ REGRESSION: Garage Area
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | repo_dir=datafun-07-regression
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | python=3.14.5
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | os=Windows 11
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | shell=powershell
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | cwd=notebooks
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | github_actions=False
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | Loading dataset: housing
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | Loaded: 2930 rows, 83 columns
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | Fitted line: SalePrice = 237.935 * Garage Area + 68306.1
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | R²: 0.4101
# 2026-06-24 16:14:44 | INFO | JT‑XYZ | RMSE: 61,354.78
# 2026-06-24 16:14:45 | INFO | JT‑XYZ | XYZ regression complete.
# 2026-06-24 16:14:45 | INFO | JT‑XYZ | ========================
# ...

# %% [markdown]
# ## Summary
#
# In this notebook, we:
#
# ### ✅ Loaded and inspected the Ames Housing dataset
# - Confirmed row and column counts
# - Previewed the first few records
#
# ### ✅ Ran three simple XYZ regressions
# Each model examined the relationship between **SalePrice** and one feature:
# - Garage Area
# - 1st Floor Square Footage
# - Total Rooms Above Ground
#
# For each regression, we:
# - Logged slope, intercept, R², and RMSE
# - Generated red–white–blue scatter and residual plots
# - Saved all visuals to `docs/artifacts/xyz/`

# %% [markdown]
# ## 📘 Project Summary: Ames Housing XYZ Regression Analysis
#
# This project provides a clear, reproducible workflow for performing simple linear regression on the Ames Housing dataset. The goal is to understand how individual home features relate to **SalePrice** using three focused, interpretable models.
#
# ### 🔍 What This Project Does
#
# - Loads and inspects the Ames Housing dataset
# - Selects three key predictors of interest:
#   - Garage Area
#   - 1st Floor Square Footage
#   - Total Rooms Above Ground
# - Runs a simple linear regression for each feature
# - Logs slope, intercept, R², and RMSE for transparent evaluation
# - Generates red–white–blue scatterplots and residual plots
# - Saves all visuals to `docs/artifacts/xyz/` for documentation and reuse
#
# ### 🎯 Why It Matters
#
# This workflow provides a clean, educational example of:
# - Building simple regression models
# - Understanding how individual features influence home prices
# - Producing consistent, high‑quality visual artifacts
# - Maintaining reproducibility through logging and structured analysis
#
# ### 📁 Final Result
#
# You now have a complete, notebook‑based version of the `ames_regression_xyz.py` module — including:
# - Data loading
# - Model execution
# - Logging
# - Visual output
#
# All packaged in a format suitable for learning, reuse, and extension.
